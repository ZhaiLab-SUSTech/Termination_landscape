# %%
# %config InlineBackend.figure_format = 'retina'

from matplotlib import pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.font_manager as font_manager
import matplotlib as mpl
import matplotlib.patches as mp
import seaborn as sns

font_dirs = ["/public/home/mowp/test/fonts/"]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    font_manager.fontManager.addfont(font_file)
    
plt.rcParams["font.family"] = "Arial"
plt.rcParams['font.size'] = 12
plt.rcParams['svg.fonttype'] = 'none'

# %%
import pandas as pd
import numpy as np

# %%
araport11_isoform_path = '/public/home/mowp/db/Arabidopsis_thaliana/representative_gene_model/araport11.representative.gene_model.bed'
araport11_isoform = pd.read_csv(araport11_isoform_path, sep='\t', 
                                names=['chrom', 'chromStart', 'chromEnd', 'name', 
                                       'score', 'strand', 'thickStart', 'thickEnd', 
                                       'itemRgb', 'blockCount', 'blockSizes', 'blockStarts']
                               )
araport11_isoform['gene_id'] = araport11_isoform['name'].map(lambda x: x.split('.')[0])
araport11_isoform.set_index('gene_id', inplace=True)

araport11_isoform_path = '/public/home/mowp/db/Arabidopsis_thaliana/representative_gene_model/araport11.representative.gene_model.bed.gz'

# %%
import sys
sys.path.append('/public/home/mowp/workspace/mowp_scripts/tools/pyIGV')

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport coverage_plot

# %% [markdown]
# # Examples

# %% [markdown]
# ## AT4G36195

# %%
gene_id = 'AT4G36195'
chrom, start, end, mRNA_id, _, strand, *_ = araport11_isoform.loc[gene_id]
end = 17130459
igv = coverage_plot.COV(chrom, start, end, strand=strand)

igv.add_gene_model(
    araport11_isoform_path,
    gene_list = {'AT4G36195.1', 'AT4G36197.1'},
)

infile = '/public/home/mowp/workspace/termination/cbRNA_pool/elongating_data/cbRNA.elongating.bam'
igv.add_bam(infile, color='#3182BD', gene_list={gene_id})

infile = '/public/home/mowp/test/mnase_seq_nucmap/danpos_result/pooled/aligned_data_SRR957780.smooth.bw'
igv.add_bw(infile, color='#6ECDDC')

infile = '/public/home/mowp/data/public_data/epigentics_data/MED_GSE143831/bw_files/col_H3K4me3_ChIPseq_GSM4275144.sorted.rmdup.CPM.bw'
igv.add_bw(infile, color='#782F9A', data_range=[0, 6])

infile = '/public/home/mowp/data/public_data/epigentics_data/MED_GSE143831/bw_files/col_H3K36me3_ChIPseq_GSM4275147.sorted.rmdup.CPM.bw'
igv.add_bw(infile, color='#782F9A', data_range=[0, 6])

infile = '/public/home/mowp/data/public_data/epigentics_data/MED_GSE143831/bw_files/col_H3K27me3_ChIPseq_GSM4275146.sorted.rmdup.CPM.bw'
igv.add_bw(infile, color='#782F9A', data_range=[0, 6])

infile = '/public/home/mowp/data/public_data/epigentics_data/MED_GSE143831/bw_files/col_H3K9me2_ChIPseq_GSM4275145.sorted.rmdup.CPM.bw'
igv.add_bw(infile, color='#782F9A', data_range=[0, 6])

infile = '/public/home/mowp/data/bs_seq/20210908_bs_seq_xrn3/bw_files/col0_wgbs.methratio.cg.bw'
igv.add_bw(infile, color='#008000', data_range=[0, 1])

infile = '/public/home/mowp/data/bs_seq/20210908_bs_seq_xrn3/bw_files/xrn3_wgbs.methratio.chg.bw'
igv.add_bw(infile, color='#0404FF', data_range=[0, 1])

infile = '/public/home/mowp/data/bs_seq/20210908_bs_seq_xrn3/bw_files/xrn3_wgbs.methratio.chh.bw'
igv.add_bw(infile, color='#FF1A1A', data_range=[0, 1])

ax = igv.plot(height=6, width=4, gene_track_height=3)
plt.savefig(f'{gene_id}.cov.svg')
plt.xlim()
# Out:
# (17127021.0, 17130459.0)

# %% [markdown]
# ## AT1G09130

# %%
gene_id = 'AT1G09130'
chrom, start, end, mRNA_id, _, strand, *_ = araport11_isoform.loc[gene_id]
start = 2938790
igv = coverage_plot.COV(chrom, start, end, strand=strand)

igv.add_gene_model(
    araport11_isoform_path,
    gene_list = {'AT1G09130.3', 'AT1G09110.1'},
)

infile = '/public/home/mowp/workspace/termination/cbRNA_pool/elongating_data/cbRNA.elongating.bam'
igv.add_bam(infile, color='#3182BD', gene_list={gene_id})

infile = '/public/home/mowp/test/mnase_seq_nucmap/danpos_result/pooled/aligned_data_SRR957780.smooth.bw'
igv.add_bw(infile, color='#6ECDDC')

infile = '/public/home/mowp/data/public_data/epigentics_data/MED_GSE143831/bw_files/col_H3K4me3_ChIPseq_GSM4275144.sorted.rmdup.CPM.bw'
igv.add_bw(infile, color='#782F9A', data_range=[0, 6])

infile = '/public/home/mowp/data/public_data/epigentics_data/MED_GSE143831/bw_files/col_H3K36me3_ChIPseq_GSM4275147.sorted.rmdup.CPM.bw'
igv.add_bw(infile, color='#782F9A', data_range=[0, 6])

infile = '/public/home/mowp/data/public_data/epigentics_data/MED_GSE143831/bw_files/col_H3K27me3_ChIPseq_GSM4275146.sorted.rmdup.CPM.bw'
igv.add_bw(infile, color='#782F9A', data_range=[0, 6])

infile = '/public/home/mowp/data/public_data/epigentics_data/MED_GSE143831/bw_files/col_H3K9me2_ChIPseq_GSM4275145.sorted.rmdup.CPM.bw'
igv.add_bw(infile, color='#782F9A', data_range=[0, 6])

infile = '/public/home/mowp/data/bs_seq/20210908_bs_seq_xrn3/bw_files/col0_wgbs.methratio.cg.bw'
igv.add_bw(infile, color='#008000', data_range=[0, 1])

infile = '/public/home/mowp/data/bs_seq/20210908_bs_seq_xrn3/bw_files/xrn3_wgbs.methratio.chg.bw'
igv.add_bw(infile, color='#0404FF', data_range=[0, 1])

infile = '/public/home/mowp/data/bs_seq/20210908_bs_seq_xrn3/bw_files/xrn3_wgbs.methratio.chh.bw'
igv.add_bw(infile, color='#FF1A1A', data_range=[0, 1])

ax = igv.plot(height=6, width=4, gene_track_height=3)
plt.savefig(f'{gene_id}.cov.svg')
plt.xlim()
# Out:
# (2942288.0, 2938790.0)

# %% [markdown]
# ## AT1G73540

# %%
gene_id = 'AT1G73540'
chrom, start, end, mRNA_id, _, strand, *_ = araport11_isoform.loc[gene_id]
start = 27640985
igv = coverage_plot.COV(chrom, start, end, strand=strand)

igv.add_gene_model(
    araport11_isoform_path,
    gene_list = {'AT1G73540.1', 'AT1G73530.1', 'AT1G73510.1'},
)

log_scale = True

infile = '/public/Zhaijx/ALLDATA/OnlineDB/AthRNA/05.newLib/04.complete/FQMAP/SRX2598378.rm.bam'
igv.add_bam(infile, color='#3182BD', chrom_prefix='chr', log_scale=log_scale)

infile = '/public/Zhaijx/ALLDATA/OnlineDB/AthRNA/05.newLib/04.complete/FQMAP/SRX2598381.rm.bam'
igv.add_bam(infile, color='#3182BD', chrom_prefix='chr', log_scale=log_scale)

ax = igv.plot(height=2, width=6, gene_track_height=3)
plt.savefig(f'{gene_id}.cov.svg')

# %%
gene_id = 'AT1G73540'
chrom, start, end, mRNA_id, _, strand, *_ = araport11_isoform.loc[gene_id]
start = 27640985
igv = coverage_plot.COV(chrom, start, end, strand=strand)

igv.add_gene_model(
    araport11_isoform_path,
    gene_list = {'AT1G73540.1', 'AT1G73530.1', 'AT1G73510.1'},
)

log_scale = False

# CG
infile = '/public/home/mowp/data/bs_seq/20210908_bs_seq_xrn3/bw_files/col0_wgbs.methratio.cg.bw'
igv.add_bw(infile, color=pal[7], data_range=[0, 1])

infile = '/public/home/mowp/data/bs_seq/20210908_bs_seq_xrn3/bw_files/xrn3_wgbs.methratio.cg.bw'
igv.add_bw(infile, color=pal[7], data_range=[0, 1])

ax = igv.plot(height=2, width=10, gene_track_height=3)
plt.savefig(f'{gene_id}.cov.svg')

# %% [markdown]
# ## AT2G33830

# %%
igv = coverage_plot.COV('2', 14308370, 14310608, strand='-')

igv.add_gene_model(
    araport11_isoform_path,
)

# plaNET-seq
infile = '/public/home/lab-zhai/edit_share/jbrowse/tair10/Kindgren_2019_GSE131733/s01_WT_RT_rep1/aligned_data/s01_WT_RT_rep1.bam'
igv.add_bam(infile, color='#8BB87F')
# pNET-seq
infile = '/public/home/mowp/test/net_seq_test/aligned_data/mNET_Ser2P_rep2_GSM2974954.sorted.rmdup.bam'
igv.add_bam(infile, color='#8BB87F')
# GRO-seq
infile = '/public/home/mowp/test/GRO_seq/GRO_seq_GSE100010_NatPlant_2018/GROseq_col_rep1_GSM2667813/aligned_data/GROseq_col_rep1_GSM2667813.sorted.rmdup.bam'
igv.add_bam(infile, color='#5595A8')
infile = '/public/home/mowp/test/GRO_seq/GRO_seq_GSE109974_NatPlant_2018/GSM2974947_GRO-seq_rep1/aligned_data/GSM2974947_GRO-seq_rep1.sorted.rmdup.bam'
igv.add_bam(infile, color='#5595A8')
infile = '/public/home/mowp/test/GRO_seq/GRO_seq_GSE83108_PNAS_2016/GRO-seq_rep1_GSM2193124/aligned_data/GRO-seq_rep1_GSM2193124.sorted.rmdup.bam'
igv.add_bam(infile, color='#5595A8')
ax = igv.plot(height=4.8, width=5.1, gene_track_height=2)
for ax_ in ax:
    ax_.patch.set_visible(False)
